# %% [markdown]
# # Handin 1 - Machine learning
#
# Group members: Whoever

# %% [markdown]
# ## Logistic Regression
# ### Implementing Logistic Regression
# In this exercise we were asked to implement logistic regression and test it.
# We were given starter code in the file **logistic_regression.py**.
# We implemented the following functions:
# * logistic
# * predict
# * score
# * cost_grad
# * fit

# %%
# %pip install nbconvert
# Out:
# Requirement already satisfied: nbconvert in /opt/homebrew/Cellar/jupyterlab/4.5.7_3/libexec/lib/python3.14/site-packages (7.17.1)
# Requirement already satisfied: beautifulsoup4 in /opt/homebrew/Cellar/jupyterlab/4.5.7_3/libexec/lib/python3.14/site-packages (from nbconvert) (4.14.3)
# Requirement already satisfied: bleach!=5.0.0 in /opt/homebrew/Cellar/jupyterlab/4.5.7_3/libexec/lib/python3.14/site-packages (from bleach[css]!=5.0.0->nbconvert) (6.3.0)
# Requirement already satisfied: defusedxml in /opt/homebrew/Cellar/jupyterlab/4.5.7_3/libexec/lib/python3.14/site-packages (from nbconvert) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in /opt/homebrew/Cellar/jupyterlab/4.5.7_3/libexec/lib/python3.14/site-packages (from nbconvert) (3.1.6)
# Requirement already satisfied: jupyter-core>=4.7 in /opt/homebrew/Cellar/jupyterlab/4.5.7_3/libexec/lib/python3.14/site-packages (from nbconvert) (5.9.1)
# Requirement already satisfied: jupyterlab-pygments in /opt/homebrew/Cellar/jupyterlab/4.5.7_3/libexec/lib/python3.14/site-packages (from nbconvert) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /opt/homebrew/Cellar/jupyterlab/4.5.7_3/libexec/lib/python3.14/site-packages (from nbconvert) (3.0.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in /opt/homebrew/Cellar/jupyterlab/4.5.7_3/libexec/lib/python3.14/site-packages (from nbconvert) (3.2.1)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/homebrew/Cellar/jupyterlab/4.5.7_3/libexec/lib/python3.14/site-packages (from nbconvert) (0.10.4)
# Requirement already satisfied: nbformat>=5.7 in /opt/homebrew/Cellar/jupyterlab/4.5.7_3/libexec/lib/python3.14/site-packages (from nbconvert) (5.10.4)
# Requirement already satisfied: packaging in /opt/homebrew/Cellar/jupyterlab/4.5.7_3/libexec/lib/python3.14/site-packages (from nbconvert) (26.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/homebrew/Cellar/jupyterlab/4.5.7_3/libexec/lib/python3.14/site-packages (from nbconvert) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in /opt/homebrew/Cellar/jupyterlab/4.5.7_3/libexec/lib/python3.14/site-packages (from nbconvert) (2.20.0)
# Requirement already satisfied: traitlets>=5.1 in /opt/homebrew/Cellar/jupyterlab/4.5.7_3/libexec/lib/python3.14/site-packages (from nbconvert) (5.15.0)
# Requirement already satisfied: webencodings in /opt/homebrew/Cellar/jupyterlab/4.5.7_3/libexec/lib/python3.14/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /opt/homebrew/Cellar/jupyterlab/4.5.7_3/libexec/lib/python3.14/site-packages (from bleach[css]!=5.0.0->nbconvert) (1.4.0)
# Requirement already satisfied: platformdirs>=2.5 in /opt/homebrew/Cellar/jupyterlab/4.5.7_3/libexec/lib/python3.14/site-packages (from jupyter-core>=4.7->nbconvert) (4.9.6)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/homebrew/Cellar/jupyterlab/4.5.7_3/libexec/lib/python3.14/site-packages (from nbclient>=0.5.0->nbconvert) (8.8.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/homebrew/Cellar/jupyterlab/4.5.7_3/libexec/lib/python3.14/site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert) (2.9.0.post0)
# Requirement already satisfied: pyzmq>=25.0 in /opt/homebrew/Cellar/jupyterlab/4.5.7_3/libexec/lib/python3.14/site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert) (27.1.0)
# Requirement already satisfied: tornado>=6.4.1 in /opt/homebrew/Cellar/jupyterlab/4.5.7_3/libexec/lib/python3.14/site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert) (6.5.5)
# Requirement already satisfied: fastjsonschema>=2.15 in /opt/homebrew/Cellar/jupyterlab/4.5.7_3/libexec/lib/python3.14/site-packages (from nbformat>=5.7->nbconvert) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /opt/homebrew/Cellar/jupyterlab/4.5.7_3/libexec/lib/python3.14/site-packages (from nbformat>=5.7->nbconvert) (4.26.0)
# Requirement already satisfied: attrs>=22.2.0 in /opt/homebrew/Cellar/jupyterlab/4.5.7_3/libexec/lib/python3.14/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/homebrew/Cellar/jupyterlab/4.5.7_3/libexec/lib/python3.14/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/homebrew/Cellar/jupyterlab/4.5.7_3/libexec/lib/python3.14/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /opt/homebrew/opt/rpds-py/lib/python3.14/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert) (2026.5.1)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/Cellar/jupyterlab/4.5.7_3/libexec/lib/python3.14/site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert) (1.17.0)
# Requirement already satisfied: soupsieve>=1.6.1 in /opt/homebrew/Cellar/jupyterlab/4.5.7_3/libexec/lib/python3.14/site-packages (from beautifulsoup4->nbconvert) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/homebrew/Cellar/jupyterlab/4.5.7_3/libexec/lib/python3.14/site-packages (from beautifulsoup4->nbconvert) (4.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### logistic implementation:

# %%
def logistic(z):
    """
    Helper function
    Computes the logistic function 1/(1+e^{-x}) to each entry in input vector z.

    np.exp may come in handy
    Args:
        z: numpy array shape (d,)
    Returns:
       logi: numpy array shape (d,) each entry transformed by the logistic function
    """
    logi = np.zeros(z.shape)
    ### YOUR CODE HERE

    ### END CODE
    assert logi.shape == z.shape
    return logi

# %% [markdown]
# #### predict implementation:

# %% [markdown]
# #### score implementation:

# %% [markdown]
# #### cost_grad implementation:

# %% [markdown]
# #### fit implementation:

# %% [markdown]
# ### Applying Logistic Regression
# You will test your implementation on a real-life data set obtained from the danish central business register (CVR). The data set consists of text descriptions of the purpose of a company, such as:
#
# "Selskabets formål er at drive restaurant og dertil knyttet virksomhed."
#
# together with a label indicating the so-called industry code, e.g. 561010 is the code for "Restauranter" and 620100 is the code for "Computerprogrammering".
#
# We have already written code that transforms a text description into a feature vector, so you do not need to worry about this translation. We will see later in the course how to do so. In this exercise, you will train a logistic regression classifier to classify descriptions of company purposes into the two classes "Restauranter" and "Computerprogrammering". If you want to have a look at the data, you can unzip "branchekoder_formal.gzip" and open it as a text file (keep the .gzip file in the directory). We are only extracting companies falling in the two categories 561010 and 620100.
#
# **Run python logistic_test.py** and see your in-sample and test accuracy on text classification of industry codes (real data)
#
# The code automatically saves the generated plot to include in your report. With a correct implementation and setting of learning rate, batch_size, epochs **you should get above 95 percent test accuracy.**
